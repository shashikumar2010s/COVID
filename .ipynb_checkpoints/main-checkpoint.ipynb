# %%
import numpy as np
import pandas as pd
from google.cloud import bigquery

# %%
# %load_ext google.cloud.bigquery
client = bigquery.Client()

# %%
ll
# Out:
# total 5776
# -rw-r--r--  1 jupyter  618911 Nov 13 09:22 cluster_breakout.ipynb
# drwxr-xr-x  2 jupyter    4096 Nov 12 06:33 data/
# -rw-r--r--  1 jupyter  329934 Nov 13 09:22 Fatalities.ipynb
# -rw-r--r--  1 jupyter  228196 Nov 13 09:26 infection_rate.ipynb
# -rw-r--r--  1 jupyter 3678952 Nov 13 11:03 infectionrate_vs_population.xlsx
# -rw-r--r--  1 jupyter     985 Nov 13 11:00 main.ipynb
# -rw-r--r--  1 jupyter  946449 Nov 13 09:22 predictor.ipynb
# -rw-r--r--  1 jupyter     773 Nov 13 09:49 README.txt
# -rw-r--r--  1 jupyter   20708 Nov 13 09:39 requirement.txt
# drwxr-xr-x 19 jupyter    4096 Nov 10 06:10 tutorials/
# -rw-r--r--  1 jupyter     213 Nov 13 09:37 Untitled1.ipynb
# -rw-r--r--  1 jupyter   53029 Nov 10 18:00 Untitled.ipynb

# %%
df_1 = pd.read_excel('infectionrate_vs_population.xlsx')

# %%
# df_1[df_1['location_key'] == df_1['country_code']]
df = df_1.drop(columns=['Unnamed: 0'])

# %%
df
# Out:
#             date location_key country_code  country_name  subregion1_code  \
# 0     2020-10-14           CM           CM      Cameroon              NaN
# 1     2020-10-26           JO           JO        Jordan              NaN
# 2     2020-10-05           TH           TH      Thailand              NaN
# 3     2020-09-15           SK           SK      Slovakia              NaN
# 4     2020-04-18           LK           LK     Sri Lanka              NaN
# ...          ...          ...          ...           ...              ...
# 77059 2020-05-10           LU           LU    Luxembourg              NaN
# 77060 2020-07-30           TD           TD          Chad              NaN
# 77061 2020-05-31           SL           SL  Sierra Leone              NaN
# 77062 2020-03-24           KE           KE         Kenya              NaN
# 77063 2020-03-26           XK           XK        Kosovo              NaN
#
#        subregion1_name  subregion2_code  subregion2_name  aggregation_level  \
# 0                  NaN              NaN              NaN                  0
# 1                  NaN              NaN              NaN                  0
# 2                  NaN              NaN              NaN                  0
# 3                  NaN              NaN              NaN                  0
# 4                  NaN              NaN              NaN                  0
# ...                ...              ...              ...                ...
# 77059              NaN              NaN              NaN                  0
# 77060              NaN              NaN              NaN                  0
# 77061              NaN              NaN              NaN                  0
# 77062              NaN              NaN              NaN                  0
# 77063              NaN              NaN              NaN                  0
#
#        new_confirmed  cumulative_confirmed  population  new_tested  \
# 0              108.0               21441.0  25876380.0         NaN
# 1             1968.0               55055.0  10101694.0         NaN
# 2               10.0                3600.0  69625582.0      3697.0
# 3              188.0                5768.0   5450421.0      4027.0
# 4               10.0                 254.0  21803000.0       702.0
# ...              ...                   ...         ...         ...
# 77059            9.0                3886.0    613894.0         1.0
# 77060            9.0                 935.0  15946876.0         NaN
# 77061            9.0                 861.0   7813215.0         NaN
# 77062            9.0                  25.0  52573973.0         NaN
# 77063            9.0                  88.0   1883018.0         NaN
#
#        cumulative_tested
# 0                    NaN
# 1                    NaN
# 2              1076332.0
# 3               397513.0
# 4                10494.0
# ...                  ...
# 77059             3124.0
# 77060                NaN
# 77061                NaN
# 77062                NaN
# 77063                NaN
#
# [77064 rows x 14 columns]

# %%
df = df_1.drop(columns=['Unnamed: 0'])
